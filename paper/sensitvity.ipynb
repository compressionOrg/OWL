# %% [markdown]
# # 折线图
# 画出每层的敏感性

# %%
import matplotlib.pyplot as plt

# %%
def plot_line_chart(sensitivity):
    # 提取层号和对应的敏感度值
    if isinstance(sensitivity, dict):
        layers = list(sensitivity.keys())
        sensitivity_values = list(sensitivity.values())
    elif isinstance(sensitivity, list):
        layers = list(range(32))  # 创建0到31的层号列表
        sensitivity_values = sensitivity  # 直接使用列表作为敏感度值

    # 创建图形
    plt.figure(figsize=(10, 6))

    # 绘制折线图
    plt.plot(layers, sensitivity_values, label='Sensitivity', color='blue')

    # 添加标签和标题
    plt.xlabel('Layer')
    plt.ylabel('Sensitivity')
    plt.title('Layer-wise Sensitivity')

    # 显示图例
    plt.legend()

    # 显示图形
    plt.show()

# %%
# weight sum
weight_sum = {
    "0": 2956909.75,
    "1": 3347716.0,
    "2": 3607236.75,
    "3": 3553950.5,
    "4": 3561231.0,
    "5": 3540112.75,
    "6": 3564193.5,
    "7": 3549619.25,
    "8": 3528030.5,
    "9": 3499246.5,
    "10": 3537051.25,
    "11": 3595023.5,
    "12": 3555154.75,
    "13": 3572590.25,
    "14": 3586630.0,
    "15": 3591842.75,
    "16": 3627092.0,
    "17": 3624674.5,
    "18": 3613630.0,
    "19": 3632841.5,
    "20": 3672115.0,
    "21": 3652010.75,
    "22": 3675822.25,
    "23": 3670768.25,
    "24": 3694488.25,
    "25": 3731009.0,
    "26": 3751108.75,
    "27": 3766064.25,
    "28": 3751076.0,
    "29": 3773787.25,
    "30": 3768116.5,
    "31": 3785582.5
}

# %%
# 计算conn sum
conn_sensitivity = {
    0: 278.9278869628906,
    1: 1537.4918212890625,
    2: 10319.986328125,
    3: 505.1446838378906,
    4: 633.3137817382812,
    5: 677.8006591796875,
    6: 687.4088745117188,
    7: 806.1181030273438,
    8: 907.0012817382812,
    9: 922.118896484375,
    10: 1150.6800537109375,
    11: 1111.157958984375,
    12: 1278.4998779296875,
    13: 1064.942138671875,
    14: 906.9503173828125,
    15: 829.887939453125,
    16: 813.708740234375,
    17: 662.8854370117188,
    18: 499.3265380859375,
    19: 425.732177734375,
    20: 342.2218017578125,
    21: 314.36492919921875,
    22: 270.3114318847656,
    23: 393.69415283203125,
    24: 287.1642150878906,
    25: 262.34912109375,
    26: 192.72348022460938,
    27: 239.73509216308594,
    28: 194.37757873535156,
    29: 231.89222717285156,
    30: 768.1707153320312,
    31: 2523.4892578125
}

# %%
plot_line_chart(weight_sum)
plot_line_chart(conn_sensitivity)

# %%
sensitivity = [
    0.5177380442619324,
    0.43287909030914307,
    0.038475602865219116,
    0.5137323141098022,
    0.5113351345062256,
    0.5119971036911011,
    0.512925386428833,
    0.5106619000434875,
    0.5105026960372925,
    0.5127089023590088,
    0.5123984217643738,
    0.5142951607704163,
    0.5134217143058777,
    0.5135967135429382,
    0.5171194076538086,
    0.5165814161300659,
    0.5165651440620422,
    0.5172523260116577,
    0.5193216800689697,
    0.5187057256698608,
    0.5209953784942627,
    0.5235236883163452,
    0.5249106884002686,
    0.5262119770050049,
    0.5277090668678284,
    0.5274878740310669,
    0.5278386473655701,
    0.5287368297576904,
    0.5264856219291687,
    0.5246604681015015,
    0.5223474502563477,
    0.48687753081321716
]

# %%
plot_line_chart(sensitivity)

# %%
# 输入数据
sensitivity = {
    0: 278.9278869628906,
    1: 1537.4918212890625,
    2: 10319.986328125,
    3: 505.1446838378906,
    4: 633.3137817382812,
    5: 677.8006591796875,
    6: 687.4088745117188,
    7: 806.1181030273438,
    8: 907.0012817382812,
    9: 922.118896484375,
    10: 1150.6800537109375,
    11: 1111.157958984375,
    12: 1278.4998779296875,
    13: 1064.942138671875,
    14: 906.9503173828125,
    15: 829.887939453125,
    16: 813.708740234375,
    17: 662.8854370117188,
    18: 499.3265380859375,
    19: 425.732177734375,
    20: 342.2218017578125,
    21: 314.36492919921875,
    22: 270.3114318847656,
    23: 393.69415283203125,
    24: 287.1642150878906,
    25: 262.34912109375,
    26: 192.72348022460938,
    27: 239.73509216308594,
    28: 194.37757873535156,
    29: 231.89222717285156,
    30: 768.1707153320312,
    31: 2523.4892578125
}

# %%
# 计算权重
sensitivity = {
    "0": 2956909.75,
    "1": 3347716.0,
    "2": 3607236.75,
    "3": 3553950.5,
    "4": 3561231.0,
    "5": 3540112.75,
    "6": 3564193.5,
    "7": 3549619.25,
    "8": 3528030.5,
    "9": 3499246.5,
    "10": 3537051.25,
    "11": 3595023.5,
    "12": 3555154.75,
    "13": 3572590.25,
    "14": 3586630.0,
    "15": 3591842.75,
    "16": 3627092.0,
    "17": 3624674.5,
    "18": 3613630.0,
    "19": 3632841.5,
    "20": 3672115.0,
    "21": 3652010.75,
    "22": 3675822.25,
    "23": 3670768.25,
    "24": 3694488.25,
    "25": 3731009.0,
    "26": 3751108.75,
    "27": 3766064.25,
    "28": 3751076.0,
    "29": 3773787.25,
    "30": 3768116.5,
    "31": 3785582.5
}

# %%
# 提取层号和对应的敏感度值
layers = list(sensitivity.keys())
sensitivity_values = list(sensitivity.values())

# 创建图形
plt.figure(figsize=(10, 6))

# 绘制折线图
plt.plot(layers, sensitivity_values, label='Sensitivity', color='blue')

# 添加标签和标题
plt.xlabel('Layer')
plt.ylabel('Sensitivity')
plt.title('Layer-wise Sensitivity')

# 显示图例
plt.legend()

# 显示图形
plt.show()
